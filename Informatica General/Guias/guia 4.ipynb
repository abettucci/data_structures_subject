# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def mostrarMatriz(matriz):
  for i in range(len(matriz)):
    print("\n")
    for j in range(len(matriz[0])):
      print(matriz[i][j], end = "\t")

def obtenerGanador(lista, matriz):
  minimo = 0
  ganador = ""
  for i in range(len(matriz)):
    suma = 0
    for j in range(len(matriz[0])):
      suma += matriz[i][j]
    if minimo == 0 or suma < minimo:
      minimo = suma
      ganador = lista[i]
  return ganador

def obtenerGanadorEtapa(lista, matriz, etapa):
  minimo = 0
  ganador = ""
  for i in range(len(matriz)):
    if minimo == 0 or matriz[i][etapa-1] < minimo:
      minimo = matriz[i][etapa-1]
      ganador = lista[i]
  return ganador

def ganadoresPorEtapa(lista, matriz):
  for etapa in range(len(matriz[0])):
    ganador = obtenerGanadorEtapa(lista, matriz,etapa + 1)
    print("\nEl ganador de la etapa ", etapa + 1, "es:", ganador)


ciclistas = ['Pere_Porcar', 'Joan_Beltran', 'Lledó_Fabra']
tiempo = [[10092.0,12473.1, 13732.3, 10232.1, 10332.3],[11726.2, 11161.2, 12272.1, 11292.0, 12534.0],[10193.4, 10292.1, 11712.9, 10133.4, 11632.0]]

print(ciclistas)
mostrarMatriz(tiempo)
ganador = obtenerGanador(ciclistas, tiempo)

print("\nEl ganador es:", ganador)

etapa = int(input("Elija una etapa:"))
ganador = obtenerGanadorEtapa(ciclistas, tiempo, etapa)
print("\nEl ganador de la etapa ", etapa, "es:", ganador)
ganadoresPorEtapa(ciclistas, tiempo)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from math import sqrt
#Funciones
def solucionCuadratica(a,b,c):
  solucion = [None, None]
  if a != 0:
    disc = b*b -4*a*c
    if disc >= 0:
      solucion[0] = (-b+sqrt(disc))/(2*a)
      solucion[1] = (-b-sqrt(disc))/(2*a)
  return solucion

#Programa Principal
a = float(input("Coeficiente a:"))
b = float(input("Coeficiente b:"))
c = float(input("Coeficiente c:"))
solucion = solucionCuadratica(a,b,c)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def letras(lista):
  maxmin=[None,None]
  for i in range(len(lista)):
    if maxmin[0] == None or maxmin[0] >lista[i]:
      maxmin[0] = lista[i] #guardo la menor
    if maxmin[1] == None or maxmin[1] <lista[i]:
      maxmin[1] = lista[i]
  return maxmin
#Programa Principal
lista = ["hola", "es", "maxi", "menos","esto","este","auto"]
print(lista)
maxmin = letras(lista)
print(maxmin)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def unir(lista1, lista2):
  comunes = []
  i = 0
  while i < len(lista1):
    if lista1[i] in lista2 and lista1[i] not in comunes:
      comunes += [lista1[i]]
    i+=1
  return comunes

lista1=[1,2,1]
lista2=[2,3,2,4]
rta=unir(lista1,lista2)
print(rta)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def copiar(listaD, lista):
  i = 0
  while i < len(lista):
    if lista[i] not in listaD:
      listaD+=[lista[i]]
    i+=1
  return listaD

def union(lista1, lista2):
  todos = []
  todos = copiar(todos, lista1)
  todos = copiar(todos, lista2)
  return todos

lista1=[1,2,1]
lista2=[2,3,2,4]
rta=union(lista1,lista2)
print(rta)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def union(lista1,lista2):
  elemento=[]
  for i in range(len(lista1)):
    if lista1[i] not in lista2:
      elemento+=[lista1[i]]
  return elemento

lista1=[1,2,1]
lista2=[2,3,2,4]
rta=union(lista1,lista2)
print(rta)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def impares(lista):
  nueva=[]
  for i in range(len(lista)):
    if lista[i]%2!=0:
      nueva.append(lista[i])
  return nueva

lista=[1,2,3,4,5]
rta=impares(lista)
print(rta)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def letras(lista,letra):
  nueva=[]
  for nombre in lista:
    if nombre[0]==letra:
      nueva.append(nombre)
  return nueva

lista=["Mili","Agus","Mario","Jose"]
letra=input("ingrese letra")
rta=letras(lista,letra)
print(rta)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def es_primo(num):
  es = True
  div = 2
  while div < num and es==True:
    if num%div == 0:
      es = False
    div+=1
  return es

def filtraPrimos(lista):
  primos =[]
  for i in range(len(lista)):
    if es_primo(lista[i]):
      primos+=[lista[i]]
  return primos


lista=[1,2,3,45,6]
rta=filtraPrimos(lista)
print(rta)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def productoCartesiano(A,B):
  lista = []
  for i in range(len(A)):
    for j in range(len(B)):
      elemento = [A[i],B[j]]
      lista+=[elemento]
  return lista

lista=[1,2,3]
lista2=[2,5]
rta= productoCartesiano(lista,lista2)
print(rta)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def unir(lista):
  for i in range(len(lista)):
    lista.append(lista[i])
  return lista

lista=[1,2,3]
rta=unir(lista)
print(rta)
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
#Diseña una funcion que reciba una lista y devuelva otra lista cuyo resultados sea
#la lista inicial y la lista a la inversa

def unir(lista):
  n=len(lista)
  for i in range(n):
    lista.append(n-i)
    
  return lista
lista=[1,2,3]
rta=unir(lista)
print(rta)
# Out:
# [1, 2, 3, 3, 2, 1]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def inversa(lista):
  n=len(lista)
  nueva=[]
  for i in range(n):
    nueva += [lista[n-i-1]]
  return nueva


lista=[1,2,3]
rta=inversa(lista)
print(rta)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def sumaDiagonal(matriz):
  filas = len(matriz)
  columnas = len(matriz[0])
  if filas==columnas:
    suma = 0
    for i in range(filas):
      suma+=matriz[i][i]
    return suma
  else:
    return None

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from random import*

def crear_matriz(m,n):
  matriz=[None]*m
  for i in range(m):
    matriz=[None]*n
  return matriz

def cargar_matriz(matriz):
  for i in range(len(matriz)):
    for j in range(matriz[0]):
      matriz[i][j]=randint(-1,10)

def mostar_matriz(matriz):
  for i in range(len(matriz)):
    print("\nAlumno ", i+1,":", end="\t")
    for j in range(len(matriz[0])):
      print(matriz[i][j], end = "\t")
  print('\n')

def obtenerEntregados(matriz, alumno):
  cont=0
  for j in range(len(matriz[alumno-1])):
    if matriz[alumno-1][j] > -1:
      cont+=1
  return cont

def obtenerMediaEntregados(matriz, alumno):
  cont = 0
  suma = 0
  for j in range(len(matriz[alumno-1])):
    if matriz[alumno-1][j] > -1:
      suma +=matriz[alumno-1][j]
    cont+=1
    if cont>0:
      media = suma/cont
    else:
      media = 0
  return media

def obtenerMediaEjercicios(matriz, alumno):
  cont = 0
  suma = 0
  for j in range(len(matriz[alumno-1])):
    if matriz[alumno-1][j] > -1:
      suma +=matriz[alumno-1][j]
      cont+=1
    if cont==len(matriz[alumno-1]):
      media = suma/cont
    else:
      media = 0
 return media

def totalEntregadosMediaSuperior(matriz, tope):
  alumnos = len(matriz)
  cont = 0
  for i in range(alumnos):
    media = obtenerMediaEjercicios(matriz, i)
    if media>tope:
      cont+=1
  return cont

def obtenerMaxima(matriz, ejercicio):
  maxima = -1
  for i in range(len(matriz)):
    nota = matriz[i][ejercicio-1]
    if nota != -1 and nota > maxima:
      maxima = nota
  return maxima

def obtenerMinima(matriz, ejercicio):
  minima = 11
  for i in range(len(matriz)):
    nota = matriz[i][ejercicio-1]
    if nota != -1 and nota < minima:
      minima = nota
  return minima

def obtenerPresentaciones(matriz, ejercicio):
  cont = 0
  for i in range(len(matriz)):
    nota = matriz[i][ejercicio-1]
    if nota != -1 :
      cont+=1
  return cont

def obtenerMediaPresentaciones(matriz, ejercicio):
  cont = 0
  suma = 0
  for i in range(len(matriz)):
    nota = matriz[i][ejercicio-1]
    if nota != -1 :
      cont+=1
      suma+=nota
    if cont == 0:
      media = 0
    else:
      media = suma/cont
  return media

m = int(input("Ingrese cantidad de estudiantes: "))
n = int(input("Ingrese cantidad de notas obtenidas en la semana: "))
matriz = crearMatrizNula(m,n)
cargarMatriz(matriz)
mostrarMatriz(matriz)
alumno = int(input("Ingrese numero de alumno:"))
entregados = obtenerEntregados(matriz, alumno)
print("El alumno ", alumno," entrego ", entregados, " ejercicios.")
alumno = int(input("Ingrese numero de alumno:"))
media = obtenerMediaEntregados(matriz, alumno)
print("El alumno ", alumno," obtuvo una media de ", media, " sobre los ejercicios entregados.")
alumno = int(input("Ingrese numero de alumno:"))
media = obtenerMediaEjercicios(matriz, alumno)
if media == 0:
  print("El alumno no entrego todos los ejercicios.")
else:
  print("El alumno ", alumno," obtuvo una media de ", media, " sobre los ejercicios que fueron entregados todos.")
total = totalEntregadosMediaSuperior(matriz, 3.5)
print("El total de alumnos que han entregado todos los ejercicios y tienen una media superior a 3,5 es:", total)
ejercicio = int(input("Ingrese numero de ejercicio:"))
presentaciones= obtenerPresentaciones(matriz, ejercicio)
print("El ejercicio fue presentado por ", presentaciones," alumnos.")
ejercicio = int(input("Ingrese numero de ejercicio:"))
mediapresent= obtenerMediaPresentaciones(matriz, ejercicio)
print("El ejercicio obtuvo un promedio de ", mediapresent," entre los alumnos que lo entregaron.")
ejercicio = int(input("Ingrese nnumero de ejercicio:"))
notabaja=obtenerMinima(matriz, ejercicio)
if notabaja == -1:
print("Nadie entrego ese ejercicio!!")
else:
print("La nota mas baja para el ejercicio ", ejercicio, " fue: ",notabaja)
ejercicio = int(input("Ingrese numero de ejercicio:"))
notaalta=obtenerMaxima(matriz, ejercicio)
if notaalta == 11:
  print("Nadie entrego ese ejercicio!!")
else:
  print("La nota mas alta para el ejercicio ", ejercicio, " fue: ",notaalta)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from random import
def crear_matriz(m,n):
  matriz=[None]*m
  for i in range(m):
    matriz=[None]*n
  return matriz

def cargar_matriz(matriz):
  for i in range(len(matriz)):
    for j in range(matriz[0]):
      matriz[i][j]=randint(-10,10)

def mostrarMatriz(matriz):
  for i in range(len(matriz)):
    print("\n", i+1,":", end="\t")
    for j in range(len(matriz[0])):
      print(matriz[i][j], end = "\t")
  print('\n')

def diferencia(matriz1, matriz2):
  m = len(matriz1)
  n = len(matriz1[0])
  matriz = crearMatrizNula(m,n)
  for i in range(m):
    for j in range(n):
      matriz[i][j]=matriz1[i][j]-matriz2[i][j]
  return matriz
#Programa Principal
m = int(input("Ingrese cantidad de filas:"))
n = int(input("Ingrese cantidad de columnas:"))
matriz1 = crearMatrizNula(m,n)
cargarMatriz(matriz1)
mostrarMatriz(matriz1)
matriz2 = crearMatrizNula(m,n)
cargarMatriz(matriz2)
mostrarMatriz(matriz2)
matrizDiferencia = diferencia(matriz1, matriz2)
mostrarMatriz(matrizDiferencia)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from random import*

def crear_matriz(m,n):
  mat=[None]*m
  for i in range(m):
    mat[i]=[None]*n
  return mat

def cargar_matriz(mat):
  for i in range(len(mat)):
    for j in range(len(mat[0])):
      mat[i][j]=randint(-10,10)

def mostrar_matriz(matriz):
  for i in range(len(matriz)):
    print("\n")
    for j in range(len(matriz[0])):
      print(matriz[i][j], end = "\t")

def multiplicar(matriz,x):
  a=len(matriz)
  b=len(matriz[0])
  nueva=crear_matriz(m,n)
  for i in range(a):
    for j in range(b):
      nueva[i][j]=matriz[i][j]*x
  return nueva


m=int(input("ingrese numero de filas:"))
n=int(input("ingrese numero de columnas"))
x=int(input("elija numero a multiplicar"))
mat=crear_matriz(m,n)
cargar_matriz(mat)
print("la matriz es:")
mostrar_matriz(mat)
new=multiplicar(mat,x)
print("la matrzi multiplicada por",x,"es:")
mostrar_matriz(new)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from random import*

def crear_matriz(m,n):
  mat=[None]*m
  for i in range(m):
    mat[i]=[None]*n
  return mat

def cargar_matriz(mat):
  for i in range(len(mat)):
    for j in range(len(mat[0])):
      mat[i][j]=randint(-10,10)

def mostrar_matriz(matriz):
  for i in range(len(matriz)):
    print("\n")
    for j in range(len(matriz[0])):
      print(matriz[i][j], end = "\t")

def transpuesta(mat):
  n=len(mat)
  m=len(mat[0])
  nueva=crear_matriz(m,n)
  for i in range(m):
    for j in range(n):
      nueva[i][j]=mat[j][i]
  return nueva

m=int(input("ingrese numero de filas:"))
n=int(input("ingrese numero de columnas"))
mat=crear_matriz(m,n)
cargar_matriz(mat)
mostrar_matriz(mat)
trans=transpuesta(mat)
mostrar_matriz(trans)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from random import*

def crear_matriz(m,n):
  mat=[None]*m
  for i in range(m):
    mat[i]=[None]*n
  return mat

def cargar_matriz(mat):
  for i in range(len(mat)):
    for j in range(len(mat[0])):
      mat[i][j]=randint(-10,10)

def mostrar_matriz(matriz):
  for i in range(len(matriz)):
    print("\n")
    for j in range(len(matriz[0])):
      print(matriz[i][j], end = "\t")

def sumaFila(matriz, fila):
  m = len(matriz[0])
  suma = 0
  for i in range(m):
    suma += matriz[fila][i]
  return suma

def sumaColumna(matriz, col):
  n = len(matriz)
  suma = 0
  for i in range(n):
    suma += matriz[i][col]
  return suma

def sumaFilasColumnas(matriz):
  respuesta = False
  n = len(matriz)
  m = len(matriz[0])
  suma = sumaFila(matriz, 0)
  i = 1
  while i < n and suma == sumaFila(matriz,i):
    i+=1
  if i==n:
    print("Todas las filas suman lo mismo:", suma)
    j = 0
    while j < m and suma == sumaColumna(matriz, j):
      j+=1
    if j == m:
      respuesta = True
  return respuesta

m=int(input("ingrese numero de filas:"))
n=int(input("ingrese numero de columnas"))
mat=crear_matriz(m,n)
cargar_matriz(mat)
mostrar_matriz(mat)
if sumaFilasColumnas(mat):
 print("La suma de los elementos de cualquiera de las filas es igual a la suma de los elementos de cualquiera de las columnas.")
else:
  print("las filas y las columnas no suman lo mismo")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from random import*

def crear_matriz(m,n):
  mat=[None]*m
  for i in range(m):
    mat[i]=[None]*n
  return mat

def llenar_matriz(mat):
  for i in range(len(mat)):
    for j in range(len(mat[0])):
      mat[i][j]=randint(-10,10)

def mostrar_matriz(mat):
  for i in range(len(mat)):
    print("\n")
    for j in range(len(mat[0])):
      print(mat[i][j], end = "\t")

def triangular(mat):
  es=True
  a=len(mat)
  b=len(mat[0])
  for i in range(a):
    for j in range(b):
      if i>j:
        if mat[i][j]!=0:
          es=False
  return (es)


m=int(input("ingrese numero de filas y columnas:"))
while m <0:
  m=int(input("ingrese bien"))
mat=crear_matriz(m,m)
llenar_matriz(mat)
mostrar_matriz(mat)
es=triangular(mat)
if es:
  print("es triangular")
else:
  print("no es triangular")

# %%
from random import*

def crear_matriz(m,n):
  mat=[None]*m
  for i in range(m):
    mat[i]=[None]*n
  return mat

def llenar_matriz(mat):
  for i in range(len(mat)):
    for j in range(len(mat[0])):
      mat[i][j]=str(randint(1,9))

def mostrar_matriz(mat):
  for i in range(len(mat)):
    for j in range(len(mat[0])):
      print((mat[i][j]),end="\t")
    print()

def filas(mat):
  lista = []
  a = ""
  for i in range(len(mat)):
    for j in range(len(mat[0])):
      a+= str(mat[i][j])
    lista.append(int(a))
    a=""
  return lista

def columnas(mat):
  lista=[]
  a=""
  for i in range(len(mat[0])):
    for j in range(len(mat)):
      a+= str(mat[j][i])
    lista.append(int(a))
    a=""
  return lista

def suma(lista):
  suma=0
  for i in lista:
    suma+=i
  return suma

def nuevaM(matriz,lista):
    for i in range(len(matriz)):
        for j in range(len(matriz[0])):
            a = str(lista[i])
            if j == 0:
                matriz[i][j]= a[:len(a)//2]
            if j == 1:
                matriz[i][j]= a[len(a)//2:]


m=int(input("ingrese numero de filas:"))
while m < 2 or m >10:
  m=int(input("ingrese numero de filas:"))
n=int(input("ingrese numero de columnas:"))
while n%2!=0 and( n< 2or n >10):
  n=int(input("ingrese numero de columnas:"))
mat=crear_matriz(m,n)
llenar_matriz(mat)
mostrar_matriz(mat)
fila=filas(mat)
sumf=suma(fila)
print("la suma de las filas es:",sumf,"y la lista es:",fila)
columna=columnas(mat)
sumc=suma(columna)
print("la suma de las columnas es:",sumc,"y la lista es:",columna)
matriz1 = crear_matriz(m,2)
nuevaM(matriz1,fila)
mostrar_matriz(matriz1)

# %%
def repe(lista):
  nueva=[]
  cont=0
  repe=[]
  for i in range(len(lista)):
    if lista[i] not in repe:
      repe.append(lista[i])
  for j in range(len(repe)):
    for k in range(len(lista)):
      if repe[j]==lista[k]:
        cont+=1
    nueva.append([repe[j],cont])
    cont=0
  return nueva

lista=[1,1,1,2,2,2,3,4,4,4,4,4,7,7,7,7,16,16]
rta=repe(lista)
print(rta)

# %%
from random import*

def crear_matriz(m,n):
  mat=[None]*m
  for i in range(m):
    mat[i]=[None]*n
  return mat

def llenar_matriz(mat):
  for i in range(len(mat)):
    for j in range(len(mat[0])):
      mat[i][j]=randint(0,255)

def motrar_matriz(mat):
  for i in range(len(mat)):
    for j in range(len(mat[0])):
      print((mat[i][j]),end="\t")
    print()

def recorrer_matriz(mat,x):
  listacolor=[]
  for i in range(len(mat)):
    for j in range(x,len(mat[0]),3):
      elemento=mat[i][j]
      listacolor.append(elemento)
  return listacolor

def suma(lista):
  suma=0
  for i in lista:
    suma+=i
  return suma

def ordeno(lista):
  dim = len(lista)
  for i in range(dim-1):
    for j in range(i+1,dim):
      if lista[i] > lista[j]:
        aux = lista[j]
        lista[j] = lista[i]
        lista[i] = aux
  return lista


m=int(input("ingrese numero de filas:"))
n=int(input("ingrese numero de columnas:"))
while n%3!=0:
  print("el numero de columnas debe ser multiplo de tres, vaya de nuevo")
  n=int(input("ingrese numero de columnas:"))
mat=crear_matriz(m,n)
llenar_matriz(mat)
mostrar_matriz(mat)
x=0
while x <3:
  if x==0:
    lista1=recorrer_matriz(mat,x)
    print("la lista roja es:",lista1)
    x+=1
  elif x==1:
    lista2=recorrer_matriz(mat,x)
    print("la lista verde es:",lista2)
    x+=1
  elif x==2:
    lista3=recorrer_matriz(mat,x)
    print("la lista azul es:",lista3)
    x+=1
suma1=suma(lista1)
prom1=((suma1)/len(lista1))
print("la suma de los elementos de la lista roja es:",suma1)
print("el promedio de lista rojo es:",prom1)
suma2=suma(lista2)
prom2=((suma2)/len(lista2))
print("la suma de los elementos de la lista verde es:",suma2)
print("el promedio de lista verde es:",prom2)
suma3=suma(lista3)
prom3=((suma3)/len(lista3))
print("la suma de los elementos de la lista azul es:",suma3)
print("el promedio de lista azul es:",prom3)
ordeno1=ordeno(lista1)
ordeno2=ordeno(lista2)
ordeno3=ordeno(lista3)
matriznueva=[]
matriznueva.append([ordeno1,ordeno2,ordeno3])
print(matriznueva)

# %%
from random import*

def crear_matriz(n,m):
    mat = n*[None]
    for i in range(n):
        mat[i] = (m*[None])
    return mat

def llenarM(mat):
    for i in range(len(mat)):
        for j in range(len(mat[0])):
            mat[i][j] = randint(-10,10)

def mostrarM(mat):
    dim = len(mat)
    for i in range(len(mat)):
        for j in range(len(mat[0])):
            print(mat[i][j],end="\t")
        print("\n")

def mat_dispersa(mat):
    cont = 0
    n = len(mat)
    m = len(mat[0])
    for i in range(n):
        for j in range(m):
            if mat[i][j] == 0:
                cont +=1
    proporcion = cont/(m*n)
    if proporcion > 0.5:
        return True
    else:
        return False

def almacenamiento(mat):
    n = len(mat)
    m = len(mat[0])
    lista = []
    for i in range(n):
        for j in range(m):
            if mat[i][j] != 0:
                lista.append([mat[i][j], i, j])
    return lista

def filas_nulas(mat):
    n = len(mat)
    m = len(mat[0])
    cont = 0
    cant_cero = 0
    for i in range(n):
        for j in range(m):
            if mat[i][j] == 0:
                cant_cero +=1
        if cant_cero == m:
            cont += 1
        cant_cero = 0
    return cont

def fila_distinta(mat):
    n = len(mat)
    m = len(mat[0])
    max = 0
    cont = 0
    for i in range(n):
        for j in range(m):
            if mat[i][j] != 0:
                cont += 1
        if max < cont:
            max = cont
            fila = i
            cont =0
    return fila

n = int(input('Inserte cantidad de filas (de 2 a 100): '))
m = int(input('Inserte cantidad de columnas (de 2 a 100): '))
mat = crear_matriz(n,m)
llenarM(mat)
mat = [[1,1],[0,1],[3,0]]
mostrarM(mat)
es_dispersa = mat_dispersa(mat)
#b
if es_dispersa:
    print('la matriz ingresada es dispersa')
else:
    print('la matriz ingresada no es dispersa')
#c
if es_dispersa:
    print('el almacenamiento eficiente es',almacenamiento(mat))
else:
    print('Como la matriz no es dispersa no se calcula el almacenamineto eficiente')
#d
print('la fila con mas elementos distintos de cero es:' ,fila_distinta(mat))
#e
print('cantidad de filas nulas es', filas_nulas(mat))
